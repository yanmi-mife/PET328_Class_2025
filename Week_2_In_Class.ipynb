# %% [markdown]
# ... to the only wise God - TTOWG

# %% [markdown]
# # Getting Started with Python

# %% [markdown]
# ##  In-Class Learning Activities

# %% [markdown]
# ### 1. Vital Sign Quiz

# %% [markdown]
# The purpose of this activity is as follow:
#
# + to assess the extent of compliance with the pre-class assignments (videos and readings);
# + to assess students' understanding of the materials in the pre-class assignments
#
# This quiz is not for grading purposes - rather, it is for the teaching staff to diagnose the state of the class and to focus on important points.

# %% [markdown]
# Here is the link to the quiz: https://forms.gle/B6rB244PXi2xU6XW7

# %% [markdown]
# ### 2. A Quick Re-cap of Pre-class Video/Reading

# %% [markdown]
# ### 3. Teach others what you know

# %% [markdown]
# At this point, those who have succeeded in setting up the tools will help to guide others through the process. This will be done in pairs or some small-sized groups.

# %% [markdown]
# ### 4. Group Task

# %% [markdown]
# The class will break into two groups for this task.
#
# The single line of code in the cell below assumes some preceding line(s) of code. Members of each group will brainstorm and come up with such preceding lines to make things work without error.
#
# When a group present their work, the other group will give constructive feedback.

# %%
pass

print(f'Since your reservoir has porosity of {poro}%,  and bulk volume of {bv} cubic ft, then pore volume is {pv} cubic ft.')

# %% [markdown]
# ### 5. Class Demo

# %% [markdown]
# In this activity, we will demonstrate how to use Latex to write math formulae in Jupyter Notebook.
#
# For this exercise, students will be asked to suggest some petroleum engineering formulae that they have come across in other PE modules.
#
# The LATEX cheatsheet below will be use to guide us. The following online resource may also help: https://quickref.me/latex
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 6. Brainstorm

# %% [markdown]
# The whole class will brainstorm on this task.

# %% [markdown]
# Supposing we are to build an interactive app to compute STOIIP, how do we go about it?

# %% [markdown]
# ### 7. introduction to Problem Sets
