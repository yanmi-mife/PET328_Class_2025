# %% [markdown]
# #### ... to the only wise God!

# %% [markdown]
# ### PET328 2024/2025

# %% [markdown]
# # Problem Set 0

# %% [markdown]
# ## Introduction

# %% [markdown]
# #### Purpose

# %% [markdown]
# Generally, the purpose of problem sets is to get you practise your programming and problem-solving skills with authentic tasks set in real-world contexts.

# %% [markdown]
# Specifically, the purpose of this problem set, PS0, (more like practice set) is to get you acquainted with the various tools and platforms we will be working with in the semester: GitHub, Juputer Notebook etc. Once you execute PS0, you will be good to handle subsequent problem sets.

# %% [markdown]
# #### Context

# %% [markdown]
# PS0 assumes you have set up the following working tools as demonstrated in class:
#
# - Python 3. See link to download here: https://www.python.org/downloads/
#
# ![image.png](attachment:image.png)
#
#
# - Jupyter Notebook (comes with Anaconda). See installation guide here: https://www.geeksforgeeks.org/how-to-install-anaconda-on-windows/
#    + Alternatively, you can use Google Colab, if you have a gmail account. No installation required.
#
# ![image-3.png](attachment:image-3.png)
#
#
# - A GitHub account: Sign up here: https://github.com/signup
#
# ![image-4.png](attachment:image-4.png)
#
#
# - GitHub Desktop app (for ease of interaction with GitHub). Download here: https://desktop.github.com/download/
# ![image-5.png](attachment:image-5.png)
# - A forked and cloned branch of PET328_Class_2025 GitHub repository.

# %% [markdown]
# #### Relevance

# %% [markdown]
# Real-life projects are built around teams with members collaboratively sharing files hoisted on distributed version control systems such as GitHub.
#
# Jupyter Notebook offers you an interactive platform (IDE) to interact with Python. It is great for learning and practice. Additionally, it is a one-stop-shop for your work - in it, you could work with codes, texts, visual outputs and images. In fact, this document you are now reading was prepared in Jupyter Notebook.

# %% [markdown]
# ## Access Problem File

# %% [markdown]
# You are to work on the Jupyter Notebook (.ipynb) version of this file. It is available as _PET328 Problem Set 0.ipynb_ in the PET328_Class_2025 GitHub repository: https://github.com/TTOWG/PET328_Class_2025

# %% [markdown]
# **Task 1**
#
# Having forked and cloned the course repository to your computer, locate the File _PET328 Problem Set 0.ipynb_ and open it in Jupyter environment.

# %% [markdown]
# ## Create Variables

# %% [markdown]
# **Task 2**
#
# You are about to do some volumentric computations on a new oil reservoir. You have the following information pertaining to the reservoir. Insert a new _Markdown_ Cell below this. In the new cell, create Python variables to hold the information.
#
# - Field name: _TTOWG_
# - Acreage: 40 acres
# - Average porosity: 0.2415
# - Payzone thickness: 15
# - Average initial water saturation: 0.28
# - Initial oil formation volume factor: 1.21

# %% [markdown]
# ## Write Equation with Latex

# %% [markdown]
# Sometimes, you may want to show the formulae/equations you are using for computation in Python, not just the code. Fortunately, Jupyter Notebook permits you to display such formulae if you can write them in Latex. Latex is like your _Equation Editor_ in a Word document. All you need is a few keywords and syntax. Check the _Readings_ section of this PS to access a short tutorial on Latex keywords and syntax.

# %% [markdown]
# **Task 3**
#
# Using Latex, write the formula for computing _Stock Tank Oil Initially in Place, STOIIP, (shown in the image below) into a new markdown cell.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Compute and report STOIIP value

# %% [markdown]
# **Task 4**
#
# Now that you have defined your variables, go on and write Python code to compute and report the _STOIIP_ value according to the formula above. Ensure you indicate the unit.

# %% [markdown]
# ## Further Practice

# %% [markdown]
# **Task 5+**
#
# Practice makes perfect! To further hone your skills, think of 5 other simple petroleum engineering computations and implement them as you have done for STOIIP in the preceeding tasks - create variables, write formula in Latex, compute and report value.
#
# Suggestions:
#
# + Dary flow rate computation
# + Archie equation

# %% [markdown]
# ## Commit and Push back to GitHub

# %% [markdown]
# Once you are done editing this file, you need to make it available online in your GitHub account.

# %% [markdown]
# **Task 6**
#
# _Commit_ and _Push_ your edits to your branch of the *PET328_Class_2025* repo (not to the main branch - that's mine)

# %% [markdown]
# **Task 7**
#
# Submit the URL to your branch of *PET328_Class_2025* through Moodle

# %% [markdown]
# **Task 8**
#
# From your GitHub Desktop app (or otherwise), create and send a pull request to the main branch of the repository.
